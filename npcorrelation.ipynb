# %% [markdown]
# <a href="https://colab.research.google.com/github/yangguang931230/AALU_t2/blob/main/npcorrelation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
pd.__version__ # Displays Pandas version

import matplotlib.pyplot as plt

# %%
# Read csv from a local file path
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3e3fd94d-e741-4a3b-91f5-6216eb7c066b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e3fd94d-e741-4a3b-91f5-6216eb7c066b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving corr_np.csv to corr_np.csv

# %%
# Read csv from a local file path
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b8b3d7f6-7c81-4193-af92-3d1d9e035e79" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b8b3d7f6-7c81-4193-af92-3d1d9e035e79">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving corr_np3.csv to corr_np3.csv

# %%
np = pd.read_csv('corr_np.csv')
np
# Out:
#      OID  Shape_Length  Shape_Area  ...  Pop16_59  Pop60_  WorkPop
# 0      1      0.075977    0.000309  ...      1293     395  1276.00
# 1      2      0.163984    0.000819  ...      1715     208  1685.50
# 2      3      0.124156    0.000355  ...      1036     116  1018.00
# 3      4      0.210816    0.001086  ...      1195     142  1205.00
# 4      5      0.107573    0.000553  ...      1016     348  1018.25
# ..   ...           ...         ...  ...       ...     ...      ...
# 101  102      0.061661    0.000147  ...      1117     203  1076.00
# 102  103      0.067155    0.000107  ...       596     110   637.50
# 103  104      0.024896    0.000026  ...      1097     201  1085.75
# 104  105      0.108880    0.000302  ...      1783     188  1777.00
# 105  106      0.247079    0.001695  ...      1008     254  1008.25
#
# [106 rows x 71 columns]

# %%
np.describe()
# Out:
#               OID  Shape_Length  ...      Pop60_      WorkPop
# count  106.000000    106.000000  ...  106.000000   106.000000
# mean    53.500000      0.069307  ...  265.405660  1258.738208
# std     30.743563      0.044179  ...  102.626626   347.719320
# min      1.000000      0.000077  ...   49.000000   556.500000
# 25%     27.250000      0.037251  ...  189.250000  1032.875000
# 50%     53.500000      0.061743  ...  263.000000  1204.000000
# 75%     79.750000      0.094356  ...  334.750000  1450.250000
# max    106.000000      0.247079  ...  676.000000  2796.750000
#
# [8 rows x 71 columns]

# %%
np3 = pd.read_csv('corr_np3.csv')
np3
# Out:
#      GI_perc  HH_perc  SF_perc  BE_perc  ...  DepChi  Pop16_59  Pop60_  WorkPop
# 0      0.333    0.333    0.250    0.083  ...     529      1293     395  1276.00
# 1      0.300    0.100    0.500    0.100  ...     373      1715     208  1685.50
# 2      0.200    0.500    0.200    0.100  ...     272      1036     116  1018.00
# 3      0.286    0.429    0.143    0.143  ...     263      1195     142  1205.00
# 4      0.250    0.250    0.250    0.250  ...     270      1016     348  1018.25
# ..       ...      ...      ...      ...  ...     ...       ...     ...      ...
# 101    0.222    0.556    0.111    0.111  ...     385      1117     203  1076.00
# 102    0.100    0.100    0.400    0.400  ...      96       596     110   637.50
# 103    0.200    0.400    0.300    0.100  ...     359      1097     201  1085.75
# 104    0.231    0.154    0.231    0.385  ...     368      1783     188  1777.00
# 105    0.250    0.333    0.083    0.333  ...     412      1008     254  1008.25
#
# ...

# %%
np.corr()
# Out:
#                            OID  Shape_Length  ...    Pop60_   WorkPop
# OID                   1.000000     -0.174895  ... -0.025043 -0.130589
# Shape_Length         -0.174895      1.000000  ... -0.021638 -0.176115
# Shape_Area           -0.172283      0.917761  ...  0.020761 -0.183444
# neighbourhood_type    0.950313     -0.182150  ...  0.019046 -0.107679
# Green&infrastructure -0.123660      0.124178  ...  0.343945 -0.180947
# ...                        ...           ...  ...       ...       ...
# TotPop               -0.149281     -0.174936  ...  0.024449  0.875987
# DepChi               -0.058949     -0.036020  ... -0.046114  0.094262
# Pop16_59             -0.133000     -0.172544  ... -0.240546  0.996183
# Pop60_               -0.025043     -0.021638  ...  1.000000 -0.219839
# WorkPop              -0.130589     -0.176115  ... -0.219839  1.000000
#
# [71 rows x 71 columns]

# %%
plt.plot(np.corr())

# %%
plt.figure(figsize=(16,9)) # set figure size 
plt.plot(np.corr())
plt.legend(np.head(0), loc='lower right', shadow=True)

# %%
import seaborn as sns # Seaborn is a package for data visualisation

sns.heatmap(np.corr(), cmap='coolwarm', annot=False)

# %%
sns.heatmap(np2.corr(), cmap='coolwarm', annot=False)

# %%
sns.set(rc = {'figure.figsize':(15,15)})
sns.heatmap(np3.corr(), cmap="jet", annot=False , linewidths = 0.01, square=True , xticklabels = "auto", yticklabels=True)
